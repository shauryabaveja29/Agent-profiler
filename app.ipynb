# %% [markdown]
# # Flask Setup

# %%
pip install flask
# Out:
# Requirement already satisfied: flask in c:\users\sbaveja\anaconda3\lib\site-packages (1.1.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: click>=5.1 in c:\users\sbaveja\anaconda3\lib\site-packages (from flask) (7.1.2)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\sbaveja\anaconda3\lib\site-packages (from flask) (2.11.2)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\sbaveja\anaconda3\lib\site-packages (from flask) (1.0.1)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\sbaveja\anaconda3\lib\site-packages (from flask) (1.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\sbaveja\anaconda3\lib\site-packages (from Jinja2>=2.10.1->flask) (1.1.1)
# Could not fetch URL https://pypi.org/simple/pip/: There was a problem confirming the ssl certificate: HTTPSConnectionPool(host='pypi.org', port=443): Max retries exceeded with url: /simple/pip/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1108)'))) - skipping

# %%
import os
import pandas as pd 
import numpy as np 
import flask
import pickle
from flask import Flask, render_template, request

# %%
from flask import Flask,request, url_for, redirect, render_template, jsonify
from pycaret.regression import *
import pandas as pd
import pickle
import numpy as np

# %%
import imblearn
 and (data_unseen[["Education Level"]] == 'CA')

# %% [markdown]
# # App build

# %%
app = Flask(__name__)

model = load_model('knn_for_agent_score')
cols = ['Gender', 'Age Bracket', 'Age when insurance started Bracket', 'Education Level', 'Industry Experience bucket', 'Other Family Member Involved']

@app.route('/')
def home():
    return render_template("index.html")

@app.route('/predict',methods=['POST'])
def predict():
    data_dict = request.form.to_dict()
    for keys in data_dict.keys():
        data_dict[keys] = [str.strip(data_dict[keys])]
    #final = np.array(data_dict).reshape(1, 6) 
    data_unseen = pd.DataFrame(data_dict)
    data_unseen.columns = map(str.strip,data_unseen.columns)
    if (data_unseen.iloc[0]["Education Level"] == 'CA'):
        prediction ='Hire'
    else:    
        prediction = predict_model(model, data=data_unseen)
        prediction = prediction.Label[0]
        if (int(prediction)== 1): 
            prediction ='Hire'
        else: 
            prediction ='Dont Hire'
   # prediction = str(prediction)
    return render_template('predict.html',prediction='Recommendation : {}'.format(prediction))
    #return render_template('predict.html',prediction= data_unseen)



if __name__ == '__main__':
    app.run(debug=False)
# Out:
# INFO:logs:Initializing load_model()
# INFO:logs:load_model(model_name=knn_for_agent_score, platform=None, authentication=None, verbose=True)
# Transformation Pipeline and Model Successfully Loaded
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# INFO:werkzeug: * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [12/Nov/2020 14:51:14] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [12/Nov/2020 14:51:14] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Nov/2020 14:51:17] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [12/Nov/2020 14:51:17] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Nov/2020 14:51:21] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [12/Nov/2020 14:51:21] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Nov/2020 14:51:27] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [12/Nov/2020 14:51:27] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Nov/2020 14:51:31] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [12/Nov/2020 14:51:31] "POST /predict HTTP/1.1" 200 -

# %%
loaded_model = load_model('knn_for_agent_score')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
df= pd.read_excel(r'C:\Users\sbaveja\Desktop\Agent profiler\AFter_2016_agent_data.xlsx', sheet_name = 'Sheet1')

# %%
df.iloc[0:1]
# Out:
#   Active% bucket Gender Age Bracket Age when insurance started Bracket  \
# 0    Recommended   Male       31-40                              18-20
#
#   Education Level Industry Experience bucket Other Family Member Involved
# 0              UG                        >10                           No

# %%
predict_model(loaded_model,data= df.iloc[0:100])
# Out:
#    Active% bucket  Gender Age Bracket Age when insurance started Bracket  \
# 0     Recommended    Male       31-40                              18-20
# 1      Don't hire    Male       41-50                              26-30
# 2      Don't hire    Male       31-40                              18-20
# 3      Don't hire  Female       31-40                              21-25
# 4     Recommended  Female         >50                                >35
# 5      Don't hire  Female         <30                              21-25
# 6     Recommended  Female         <30                              21-25
# 7      Don't hire    Male         >50                                >35
# 8      Don't hire    Male       31-40                              26-30
# 79     Don't hire    Male       31-40                              26-30
# 80     Don't hire    Male       41-50                              26-30
# 81     Don't hire    Male       31-40                              21-25
# 82    Recommended    Male         <30                              21-25
# 83     Don't hire    Male       31-40                              26-30
# 84     Don't hire    Male         <30                              21-25
# 85     Don't hire  Female         <30                              21-25
# 86     Don't hire    Male         >50                                >35
# 87    Recommended    Male       31-40                              31-35
# 88     Don't hire  Female         <30                              21-25
# 89     Don't hire    Male       31-40                              31-35
# 90     Don't hire    Male       41-50                              31-35
# 91    Recommended    Male         <30                              21-25
# 92     Don't hire    Male         <30                              18-20
# 93    Recommended    Male       41-50                              21-25
# 94    Recommended  Female         >50                              18-20
# 95     Don't hire    Male         >50                                >35
# 96     Don't hire    Male       31-40                              26-30
# 97    Recommended    Male       31-40                              21-25
# 98     Don't hire    Male         >50                                >35
# 99     Don't hire    Male       41-50                              26-30
#
#    Education Level Industry Experience bucket Other Family Member Involved  \
# 0               UG                        >10                           No
# 1             Grad                        >10                           No
# 2               PG                        >10                           No
# 3             Grad                        <10                           No
# 4               PG                        >10                           No
# 5               PG                        <10                          Yes
# 6               UG                        <10                           No
# 7             Grad                        <10                          Yes
# 8             Grad                        <10                          Yes
# 9               UG                        >10                           No
# 10              PG                        >10                           No
# 11            Grad                        <10                           No
# 12              UG                        <10                          Yes
# 13            Grad                        >10                           No
# 14              PG                        <10                           No
# 15            Grad                        <10                           No
# 16            Grad                        <10                          Yes
# 17              PG                        >10                           No
# 18              UG                        <10                           No
# 19            Grad                        >10                          Yes
# 20              PG                        >10                          Yes
# 21            Grad                        <10                           No
# 22              PG                        >10                           No
# 23              PG                        >10                           No
# 24              UG                        <10                          Yes
# 25              PG                        >10                           No
# 26            Grad                        <10                          Yes
# 27            Grad                        >10                           No
# 28            Grad                        <10                           No
# 29            Grad                        >10                           No
# 30              UG                        >10                          Yes
# 31            Grad                        >10                           No
# 32            Grad                        >10                          Yes
# 33              PG                        <10                           No
# 34            Grad                        >10                           No
# 35            Grad                        <10                           No
# 36            Grad                        <10                           No
# 37            Grad                        <10                           No
# 38              UG                        <10                           No
# 39              PG                        >10                           No
# 40              PG                        <10                          Yes
# 41              PG                        <10                           No
# 42            Grad                        <10                           No
# 43              PG                        <10                           No
# 44            Grad                        <10                          Yes
# 45              UG                        >10                          Yes
# 46              PG                        <10                           No
# 47              PG                        >10                           No
# 48            Grad                        >10                           No
# 49              PG                        <10                           No
# 50            Grad                        <10                          Yes
# 51              PG                        >10                           No
# 52            Grad                        <10                           No
# 53            Grad                        <10                          Yes
# 54            Grad                        <10                           No
# 55            Grad                        <10                           No
# 56            Grad                        >10                           No
# 57            Grad                        <10                           No
# 58            Grad                        >10                           No
# 59              UG                        <10                           No
# 60              UG                        <10                           No
# 61            Grad                        <10                           No
# 62            Grad                        <10                           No
# 63              UG                        <10                           No
# 64              PG                        >10                          Yes
# 65              UG                        <10                           No
# 66            Grad                        >10                           No
# 67            Grad                        <10                           No
# 68              UG                        <10                           No
# 69            Grad                        >10                           No
# 70            Grad                        >10                          Yes
# 71              UG                        <10                          Yes
# 72              PG                        <10                          Yes
# 73              PG                        >10                           No
# 74            Grad                        >10                           No
# 75            Grad                        <10                           No
# 76            Grad                        <10                           No
# 77            Grad                        <10                          Yes
# 78              UG                        <10                          Yes
# 79            Grad                        <10                           No
# 80            Grad                        >10                          Yes
# 81            Grad                        <10                           No
# 82            Grad                        <10                          Yes
# 83              PG                        <10                          Yes
# 84            Grad                        <10                           No
# 85            Grad                        <10                          Yes
# 86              UG                        <10                           No
# 87            Grad                        <10                           No
# 88            Grad                        <10                          Yes
# 89            Grad                        <10                           No
# 90              UG                        <10                           No
# 91              PG                        <10                           No
# 92            Grad                        <10                          Yes
# 93              UG                        >10                           No
# 94            Grad                        >10                           No
# 95              UG                        <10                          Yes
# 96            Grad                        <10                           No
# 97            Grad                        >10                           No
# 98              UG                        >10                          Yes
# 99              PG                        >10                           No
#
#     Label  Score
# 0       1    0.8
# 1       0    0.8
# 2       0    0.6
# 3       0    0.6
# 4       1    0.6
# 5       0    1.0
# 6       1    0.6
# 7       0    0.6
# 8       0    0.8
# 9       0    0.6
# 10      0    1.0
# 11      0    0.8
# 12      0    0.8
# 13      0    0.6
# 14      0    1.0
# 15      0    1.0
# 16      0    0.8
# 17      0    0.8
# 18      1    0.8
# 19      0    1.0
# 20      1    0.6
# 21      1    1.0
# 22      0    1.0
# 23      0    0.6
# 24      1    0.6
# 25      0    0.8
# 26      0    0.6
# 27      0    0.8
# 28      0    0.6
# 29      1    1.0
# 30      1    1.0
# 31      1    0.6
# 32      1    0.6
# 33      1    0.8
# 34      1    0.6
# 35      0    0.8
# 36      1    0.8
# 37      0    0.6
# 38      0    0.6
# 39      0    0.6
# 40      0    0.6
# 41      0    1.0
# 42      1    1.0
# 43      1    0.6
# 44      0    0.6
# 45      1    0.6
# 46      1    0.8
# 47      1    0.8
# 48      0    1.0
# 49      1    0.6
# 50      0    0.6
# 51      0    0.8
# 52      0    0.8
# 53      1    0.6
# 54      0    0.6
# 55      0    0.6
# 56      1    0.6
# 57      0    0.6
# 58      1    0.6
# 59      0    0.6
# 60      0    0.6
# 61      0    1.0
# 62      0    0.6
# 63      1    0.8
# 64      1    0.6
# 65      0    0.6
# 66      0    0.8
# 67      0    0.8
# 68      0    1.0
# 69      1    1.0
# 70      1    0.6
# 71      0    0.6
# 72      0    0.6
# 73      0    1.0
# 74      1    1.0
# 75      0    0.8
# 76      1    0.6
# 77      0    0.8
# 78      1    0.6
# 79      0    0.8
# 80      1    0.6
# 81      0    0.8
# 82      0    0.6
# 83      1    0.6
# 84      0    1.0
# 85      0    0.6
# 86      1    0.8
# 87      0    1.0
# 88      0    0.6
# 89      0    1.0
# 90      0    1.0
# 91      0    0.8
# 92      0    0.6
# 93      1    0.8
# 94      1    1.0
# 95      0    0.6
# 96      0    0.8
# 97      0    0.6
# 98      0    0.8
# 99      0    1.0
